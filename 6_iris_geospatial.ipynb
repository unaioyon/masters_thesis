# %% [markdown]
# # Wrangling the geospatial IRIS information

# %%
# Import packages
# Operational
import os

# Basic
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Geospatial
import geopandas as gpd
import fiona
from shapely import geometry

# %%
# Working directory
os.chdir("/Users/unaioyon/Desktop/masters_thesis/data/fra")

# %% [markdown]
# #### Import the data

# %%
# 2010 PARIS
iris10 = gpd.read_file("iris/geo/2010/CONTOURS-IRIS_1-0_SHP_LAMB93_R11/CONTOURS-IRIS/1_DONNEES_LIVRAISON_2017-08-00079/CONTOURS-IRIS_1-0_SHP_LAMB93_R11/IRIS_LAMB93_D75_2010/IRIS75.shp")

# %%
# 2013 PARIS
iris13 = gpd.read_file("iris/geo/2013/CONTOURS-IRIS/1_DONNEES_LIVRAISON_2013/CONTOURS-IRIS_1-0_SHP_LAMB93_R11-2013/CONTOURS-IRIS_1-0_SHP_LAMB93_D75-2013/CONTOURS-IRIS75.shp")

# %%
# 2014 PARIS
iris14 = gpd.read_file("iris/geo/2014/CONTOURS-IRIS/1_DONNEES_LIVRAISON_2014/CONTOURS-IRIS_2-0_SHP_LAMB93_D075-2014/CONTOURS-IRIS_D075.shp")

# %%
# 2014 PARIS
iris14 = gpd.read_file("iris/geo/2014/CONTOURS-IRIS/1_DONNEES_LIVRAISON_2014/CONTOURS-IRIS_2-0_SHP_LAMB93_D075-2014/CONTOURS-IRIS_D075.shp")

# %%
# 2015 FRANCE
iris15france = gpd.read_file("iris/geo/2015/CONTOURS-IRIS/1_DONNEES_LIVRAISON_2015/CONTOURS-IRIS_2-1_SHP_LAMB93_FE-2015/CONTOURS-IRIS.SHP")

# Select Paris
iris15 = iris15france[iris15france["CODE_IRIS"].astype(str).str[0:2] == "75"].copy()

# %%
# 2016 FRANCE
iris16france = gpd.read_file("iris/geo/2016/CONTOURS-IRIS/1_DONNEES_LIVRAISON_2016/CONTOURS-IRIS_2-1_SHP_LAMB93_FE-2016/CONTOURS-IRIS.SHP")

# Select Paris
iris16 = iris16france[iris16france["CODE_IRIS"].astype(str).str[0:2] == "75"].copy()

# %%
# 2017 FRANCE
iris17france = gpd.read_file("iris/geo/2017/CONTOURS-IRIS/1_DONNEES_LIVRAISON_2018-06-00105/CONTOURS-IRIS_2-1_SHP_LAMB93_FXX-2017/CONTOURS-IRIS.SHP")

# Select Paris
iris17 = iris17france[iris17france["CODE_IRIS"].astype(str).str[0:2] == "75"].copy()

# %%
# 2018 FRANCE
iris18france = gpd.read_file("iris/geo/2018/CONTOURS-IRIS/1_DONNEES_LIVRAISON_2018-07-00057/CONTOURS-IRIS_2-1_SHP_LAMB93_FXX-2018/CONTOURS-IRIS.SHP")

# Select Paris
iris18 = iris18france[iris18france["CODE_IRIS"].astype(str).str[0:2] == "75"].copy()

# %%
# 2019 FRANCE
iris19france = gpd.read_file("iris/geo/2019/CONTOURS-IRIS/1_DONNEES_LIVRAISON_2020-01-00139/CONTOURS-IRIS_2-1_SHP_LAMB93_FXX-2019/CONTOURS-IRIS.SHP")

# Select Paris
iris19 = iris19france[iris19france["CODE_IRIS"].astype(str).str[0:2] == "75"].copy()

# %%
# 2020 FRANCE
iris20france = gpd.read_file("iris/geo/2020/CONTOURS-IRIS/1_DONNEES_LIVRAISON_2020-12-00282/CONTOURS-IRIS_2-1_SHP_LAMB93_FXX-2020/CONTOURS-IRIS.SHP")

# Select Paris
iris20 = iris20france[iris20france["CODE_IRIS"].astype(str).str[0:2] == "75"].copy()

# %% [markdown]
# # 1. Checking intertemporal variation in the number of IRIS

# %%
### 2010
# Get the columns
print("Number of observations: ", iris10.shape[0])
print("Number of IRIS: ", len(iris10["DCOMIRIS"].unique()))
print(iris10.columns)
# Out:
# Number of observations:  992
# Number of IRIS:  992
# Index(['DEPCOM', 'NOM_COM', 'IRIS', 'DCOMIRIS', 'NOM_IRIS', 'TYP_IRIS',
#        'ORIGINE', 'geometry'],
#       dtype='object')

# %%
### 2013
# Get the columns
print("Number of observations: ", iris13.shape[0])
print("Number of IRIS: ", len(iris13["DCOMIRIS"].unique()))
print(iris13.columns)
# Out:
# Number of observations:  992
# Number of IRIS:  992
# Index(['DEPCOM', 'NOM_COM', 'IRIS', 'DCOMIRIS', 'NOM_IRIS', 'TYP_IRIS',
#        'ORIGINE', 'geometry'],
#       dtype='object')

# %%
### 2014
# Get the columns
print("Number of observations: ", iris14.shape[0])
print("Number of IRIS: ", len(iris14["DCOMIRIS"].unique()))
print(iris14.columns)
# Out:
# Number of observations:  992
# Number of IRIS:  992
# Index(['DEPCOM', 'NOM_COM', 'IRIS', 'DCOMIRIS', 'NOM_IRIS', 'TYP_IRIS',
#        'geometry'],
#       dtype='object')

# %%
### 2015
# Get the columns
print("Number of observations: ", iris15.shape[0])
print("Number of IRIS: ", len(iris15["CODE_IRIS"].unique()))
print(iris15.columns)
# Out:
# Number of observations:  992
# Number of IRIS:  992
# Index(['INSEE_COM', 'NOM_COM', 'IRIS', 'CODE_IRIS', 'NOM_IRIS', 'TYP_IRIS',
#        'geometry'],
#       dtype='object')

# %%
### 2016
# Get the columns
print("Number of observations: ", iris16.shape[0])
print("Number of IRIS: ", len(iris16["CODE_IRIS"].unique()))
print(iris16.columns)
# Out:
# Number of observations:  992
# Number of IRIS:  992
# Index(['INSEE_COM', 'NOM_COM', 'IRIS', 'CODE_IRIS', 'NOM_IRIS', 'TYP_IRIS',
#        'geometry'],
#       dtype='object')

# %%
### 2017
# Get the columns
print("Number of observations: ", iris17.shape[0])
print("Number of IRIS: ", len(iris17["CODE_IRIS"].unique()))
print(iris17.columns)
# Out:
# Number of observations:  992
# Number of IRIS:  992
# Index(['INSEE_COM', 'NOM_COM', 'IRIS', 'CODE_IRIS', 'NOM_IRIS', 'TYP_IRIS',
#        'geometry'],
#       dtype='object')

# %%
### 2018
# Get the columns
print("Number of observations: ", iris18.shape[0])
print("Number of IRIS: ", len(iris18["CODE_IRIS"].unique()))
print(iris18.columns)
# Out:
# Number of observations:  992
# Number of IRIS:  992
# Index(['INSEE_COM', 'NOM_COM', 'IRIS', 'CODE_IRIS', 'NOM_IRIS', 'TYP_IRIS',
#        'geometry'],
#       dtype='object')

# %%
### 2019
# Get the columns
print("Number of observations: ", iris19.shape[0])
print("Number of IRIS: ", len(iris19["CODE_IRIS"].unique()))
print(iris19.columns)
# Out:
# Number of observations:  992
# Number of IRIS:  992
# Index(['INSEE_COM', 'NOM_COM', 'IRIS', 'CODE_IRIS', 'NOM_IRIS', 'TYP_IRIS',
#        'geometry'],
#       dtype='object')

# %%
### 2020
# Get the columns
print("Number of observations: ", iris20.shape[0])
print("Number of IRIS: ", len(iris20["CODE_IRIS"].unique()))
print(iris20.columns)
# Out:
# Number of observations:  992
# Number of IRIS:  992
# Index(['INSEE_COM', 'NOM_COM', 'IRIS', 'CODE_IRIS', 'NOM_IRIS', 'TYP_IRIS',
#        'geometry'],
#       dtype='object')

# %% [markdown]
# # 2. Checking whether the geometries and/or the idenfitiers change over time

# %%
# Order the first and the last data point in time numerically to see if the identifiers coincide
sort10 = iris10.copy()
sort10.sort_values(by = "DCOMIRIS", inplace = True)
sort10.reset_index(inplace=True)

sort20 = iris20.copy()
sort20.sort_values(by = "CODE_IRIS", inplace = True)
sort20.reset_index(inplace=True)

# %%
sort = pd.DataFrame(pd.concat([sort20["CODE_IRIS"], sort20["geometry"], sort10["DCOMIRIS"], sort20["geometry"]], axis = 1))

# %%
# Checking both the head and tail leads me to conclude that they are equal. This means that there is no variation in 
# the number and identifier of IRIS in Paris in the 2010-2020 period. This is very convenient.
sort.head(30)
# Out:
#     CODE_IRIS                                           geometry   DCOMIRIS  \
# 0   751010101  POLYGON ((652096.500 6862109.600, 652081.700 6...  751010101
# 1   751010102  POLYGON ((651932.700 6861790.200, 651847.700 6...  751010102
# 2   751010103  POLYGON ((651869.000 6862406.100, 651854.700 6...  751010103
# 3   751010104  POLYGON ((651639.900 6862521.600, 651619.800 6...  751010104
# 4   751010105  POLYGON ((650369.800 6863138.100, 650369.900 6...  751010105
# 5   751010199  POLYGON ((652096.500 6862109.600, 652093.300 6...  751010199
# 6   751010201  POLYGON ((652324.600 6862635.300, 652293.600 6...  751010201
# 7   751010202  POLYGON ((651869.000 6862406.100, 651868.200 6...  751010202
# 8   751010203  POLYGON ((651811.400 6862809.800, 651809.600 6...  751010203
# 9   751010204  POLYGON ((651811.400 6862809.800, 651799.000 6...  751010204
# 10  751010205  POLYGON ((652198.800 6862680.200, 652197.200 6...  751010205
# 11  751010206  POLYGON ((651670.600 6863058.700, 651680.500 6...  751010206
# 12  751010301  POLYGON ((651280.900 6863199.300, 651318.500 6...  751010301
# 13  751010302  POLYGON ((651670.600 6863058.700, 651666.500 6...  751010302
# 14  751010303  POLYGON ((651516.300 6862666.500, 651520.900 6...  751010303
# 15  751010401  POLYGON ((650369.800 6863138.100, 650376.300 6...  751010401
# 16  751010402  POLYGON ((650990.600 6862972.600, 650965.200 6...  751010402
# 17  751020501  POLYGON ((651280.900 6863199.300, 651234.800 6...  751020501
# 18  751020502  POLYGON ((650851.100 6863568.300, 650856.100 6...  751020502
# 19  751020503  POLYGON ((651158.500 6863643.900, 651160.600 6...  751020503
# 20  751020601  POLYGON ((651670.600 6863058.700, 651662.500 6...  751020601
# 21  751020602  POLYGON ((651779.600 6863554.200, 651775.000 6...  751020602
# 22  751020701  POLYGON ((652071.700 6862909.500, 651982.500 6...  751020701
# 23  751020702  POLYGON ((651670.600 6863058.700, 651677.900 6...  751020702
# 24  751020703  POLYGON ((652120.900 6863235.500, 652045.000 6...  751020703
# 25  751020704  POLYGON ((651779.600 6863554.200, 651786.200 6...  751020704
# 26  751020801  POLYGON ((652514.800 6863489.900, 652539.500 6...  751020801
# 27  751020802  POLYGON ((652071.700 6862909.500, 652079.300 6...  751020802
# 28  751020803  POLYGON ((652120.900 6863235.500, 652138.300 6...  751020803
# 29  751020804  POLYGON ((652120.900 6863235.500, 652121.900 6...  751020804
#
#                                              geometry
# 0   POLYGON ((652096.500 6862109.600, 652081.700 6...
# 1   POLYGON ((651932.700 6861790.200, 651847.700 6...
# 2   POLYGON ((651869.000 6862406.100, 651854.700 6...
# 3   POLYGON ((651639.900 6862521.600, 651619.800 6...
# 4   POLYGON ((650369.800 6863138.100, 650369.900 6...
# 5   POLYGON ((652096.500 6862109.600, 652093.300 6...
# 6   POLYGON ((652324.600 6862635.300, 652293.600 6...
# 7   POLYGON ((651869.000 6862406.100, 651868.200 6...
# 8   POLYGON ((651811.400 6862809.800, 651809.600 6...
# 9   POLYGON ((651811.400 6862809.800, 651799.000 6...
# 10  POLYGON ((652198.800 6862680.200, 652197.200 6...
# 11  POLYGON ((651670.600 6863058.700, 651680.500 6...
# 12  POLYGON ((651280.900 6863199.300, 651318.500 6...
# 13  POLYGON ((651670.600 6863058.700, 651666.500 6...
# 14  POLYGON ((651516.300 6862666.500, 651520.900 6...
# 15  POLYGON ((650369.800 6863138.100, 650376.300 6...
# 16  POLYGON ((650990.600 6862972.600, 650965.200 6...
# 17  POLYGON ((651280.900 6863199.300, 651234.800 6...
# 18  POLYGON ((650851.100 6863568.300, 650856.100 6...
# 19  POLYGON ((651158.500 6863643.900, 651160.600 6...
# 20  POLYGON ((651670.600 6863058.700, 651662.500 6...
# 21  POLYGON ((651779.600 6863554.200, 651775.000 6...
# 22  POLYGON ((652071.700 6862909.500, 651982.500 6...
# 23  POLYGON ((651670.600 6863058.700, 651677.900 6...
# 24  POLYGON ((652120.900 6863235.500, 652045.000 6...
# 25  POLYGON ((651779.600 6863554.200, 651786.200 6...
# 26  POLYGON ((652514.800 6863489.900, 652539.500 6...
# 27  POLYGON ((652071.700 6862909.500, 652079.300 6...
# 28  POLYGON ((652120.900 6863235.500, 652138.300 6...
# 29  POLYGON ((652120.900 6863235.500, 652121.900 6...

# %%
# In terms of the geometry, it looks equal as well
sort_geom_equal = sort.iloc[:,1] == sort.iloc[:,3]
sort_geom_equal.unique()

# %% [markdown]
# # 3. Assigning IRIS to Slow Zones to construct an indicator for treatment status

# %% [markdown]
# Steps for the computation:
#  * **Import slow zone data**: subset the observations with geometry and time of implementation after removing duplicates.
#  * **Import IRIS data.**
#  * **Apply the overlay(how = intersection, keep_geom_type = False):** to obtain, iterating over IRIS, the set of slow zones lying within its boundaries.
#  * **Select variables:** % of surface of each slow zone over the IRIS surface (spatial weights in a way), slow zone geometries, IRIS code, slow zone year of implementation.
#  * **Assign treatment status:** a) if no slow zone, that IRIS is never-treated (create a dummy for never-treated), b) if several slow zones, belongs to group e such that the first slow zone was implemented in that year, c) properly assigning the value is done as follows: aggregate at the IRIS level to obtain the minimum (equivalently, the earliest) year of implementation of slow zones lying inside it, and then construct the long panel potentially in R using this.

# %%
# Import slow zone data
zones = gpd.read_file("zones_30/zones-30.shp")

# %%
# Check CRS after renaming a single IRIS file as they are all equivalent over the years
iris = iris19
iris.crs # LAMBERT93
print(iris.crs, zones.crs)

# Convert to CRS EPSG:27561 (projected for North France (Paris))
iris.to_crs("EPSG:27561", inplace = True)
zones.to_crs("EPSG:27561", inplace = True)

print(iris.crs, zones.crs)

# Reset IRIS index
iris.reset_index(inplace = True)
# Out:
# EPSG:4326 EPSG:4326
# EPSG:27561 EPSG:27561

# %%
# %%time
# Create the overlay loop

# Visualize progress
k = 0

iris_treat = gpd.GeoDataFrame()

# Identifier is CODE_IRIS
for i in iris["CODE_IRIS"]:
    # Create the object in which the overlaid dataframes will be stored iteratively
    iris_overlay = gpd.GeoDataFrame()
    
    # Create the overlay selecting the IRIS so that the intput is a (geo)dataframe
    iris_overlay = gpd.overlay(iris[iris["CODE_IRIS"] == i],
                              zones,
                              how = "intersection",
                              keep_geom_type = False)
    
    # Rename variables
    iris_overlay.rename(columns = {"CODE_IRIS": "iris", "date_arr": "date", "nom_zca": "zone_name"},
                        inplace = True)
    
    # Select variables
    iris_overlay_selected = iris_overlay[["iris", "zone_name", "date", "month", "year", "geometry"]].copy()
    
    # Generate spatial weights just in case
    # iris_overlay_selected["weights_mean"] = iris_overlay_selected["geometry"].area/iris.loc[iris["CODE_IRIS"] == i, "geometry"].area
    # iris_overlay_selected["weights_sum"] = iris_overlay_selected["geometry"].area/
    
    # Visualize progress
    k = k + 1
    print(round((k/992)*100, ndigits = 2), "percent computed")
    
    # Join to the main dataframe
    iris_treat = gpd.GeoDataFrame(pd.concat([iris_treat, iris_overlay_selected], ignore_index = True), 
                                   crs = iris_overlay_selected.crs)
    
iris_treat = iris_treat[iris_treat["iris"].notna()]

# Save the dataset
iris_treat.to_file("zones_30/iris_treatment.geojson")
# Out:
# 0.1 percent computed
# 0.2 percent computed
# 0.3 percent computed
# 0.4 percent computed
# 0.5 percent computed
# 0.6 percent computed
# 0.71 percent computed
# 0.81 percent computed
# 0.91 percent computed
# 1.01 percent computed
# 1.11 percent computed
# 1.21 percent computed
# 1.31 percent computed
# 1.41 percent computed
# 1.51 percent computed
# 1.61 percent computed
# 1.71 percent computed
# 1.81 percent computed
# 1.92 percent computed
# 2.02 percent computed
# 2.12 percent computed
# 2.22 percent computed
# 2.32 percent computed
# 2.42 percent computed
# 2.52 percent computed
# 2.62 percent computed
# 2.72 percent computed
# 2.82 percent computed
# 2.92 percent computed
# 3.02 percent computed
# 3.12 percent computed
# 3.23 percent computed
# 3.33 percent computed
# 3.43 percent computed
# 3.53 percent computed
# 3.63 percent computed
# 3.73 percent computed
# 3.83 percent computed
# 3.93 percent computed
# 4.03 percent computed
# 4.13 percent computed
# 4.23 percent computed
# 4.33 percent computed
# 4.44 percent computed
# 4.54 percent computed
# 4.64 percent computed
# 4.74 percent computed
# 4.84 percent computed
# 4.94 percent computed
# 5.04 percent computed
# 5.14 percent computed
# 5.24 percent computed
# 5.34 percent computed
# 5.44 percent computed
# 5.54 percent computed
# 5.65 percent computed
# 5.75 percent computed
# 5.85 percent computed
# 5.95 percent computed
# 6.05 percent computed
# 6.15 percent computed
# 6.25 percent computed
# 6.35 percent computed
# 6.45 percent computed
# 6.55 percent computed
# 6.65 percent computed
# 6.75 percent computed
# 6.85 percent computed
# 6.96 percent computed
# 7.06 percent computed
# 7.16 percent computed
# 7.26 percent computed
# 7.36 percent computed
# 7.46 percent computed
# 7.56 percent computed
# 7.66 percent computed
# 7.76 percent computed
# 7.86 percent computed
# 7.96 percent computed
# 8.06 percent computed
# 8.17 percent computed
# 8.27 percent computed
# 8.37 percent computed
# 8.47 percent computed
# 8.57 percent computed
# 8.67 percent computed
# 8.77 percent computed
# 8.87 percent computed
# 8.97 percent computed
# 9.07 percent computed
# 9.17 percent computed
# 9.27 percent computed
# 9.38 percent computed
# 9.48 percent computed
# 9.58 percent computed
# 9.68 percent computed
# 9.78 percent computed
# 9.88 percent computed
# 9.98 percent computed
# 10.08 percent computed
# 10.18 percent computed
# 10.28 percent computed
# 10.38 percent computed
# 10.48 percent computed
# 10.58 percent computed
# 10.69 percent computed
# 10.79 percent computed
# 10.89 percent computed
# 10.99 percent computed
# 11.09 percent computed
# 11.19 percent computed
# 11.29 percent computed
# 11.39 percent computed
# 11.49 percent computed
# 11.59 percent computed
# 11.69 percent computed
# 11.79 percent computed
# 11.9 percent computed
# 12.0 percent computed
# 12.1 percent computed
# 12.2 percent computed
# 12.3 percent computed
# 12.4 percent computed
# 12.5 percent computed
# 12.6 percent computed
# 12.7 percent computed
# 12.8 percent computed
# 12.9 percent computed
# 13.0 percent computed
# 13.1 percent computed
# 13.21 percent computed
# 13.31 percent computed
# 13.41 percent computed
# 13.51 percent computed
# 13.61 percent computed
# 13.71 percent computed
# 13.81 percent computed
# 13.91 percent computed
# 14.01 percent computed
# 14.11 percent computed
# 14.21 percent computed
# 14.31 percent computed
# 14.42 percent computed
# 14.52 percent computed
# 14.62 percent computed
# 14.72 percent computed
# 14.82 percent computed
# 14.92 percent computed
# 15.02 percent computed
# 15.12 percent computed
# 15.22 percent computed
# 15.32 percent computed
# 15.42 percent computed
# 15.52 percent computed
# 15.62 percent computed
# 15.73 percent computed
# 15.83 percent computed
# 15.93 percent computed
# 16.03 percent computed
# 16.13 percent computed
# 16.23 percent computed
# 16.33 percent computed
# 16.43 percent computed
# 16.53 percent computed
# 16.63 percent computed
# 16.73 percent computed
# 16.83 percent computed
# 16.94 percent computed
# 17.04 percent computed
# 17.14 percent computed
# 17.24 percent computed
# 17.34 percent computed
# 17.44 percent computed
# 17.54 percent computed
# 17.64 percent computed
# 17.74 percent computed
# 17.84 percent computed
# 17.94 percent computed
# 18.04 percent computed
# 18.15 percent computed
# 18.25 percent computed
# 18.35 percent computed
# 18.45 percent computed
# 18.55 percent computed
# 18.65 percent computed
# 18.75 percent computed
# 18.85 percent computed
# 18.95 percent computed
# 19.05 percent computed
# 19.15 percent computed
# 19.25 percent computed
# 19.35 percent computed
# 19.46 percent computed
# 19.56 percent computed
# 19.66 percent computed
# 19.76 percent computed
# 19.86 percent computed
# 19.96 percent computed
# 20.06 percent computed
# 20.16 percent computed
# 20.26 percent computed
# 20.36 percent computed
# 20.46 percent computed
# 20.56 percent computed
# 20.67 percent computed
# 20.77 percent computed
# 20.87 percent computed
# 20.97 percent computed
# 21.07 percent computed
# 21.17 percent computed
# 21.27 percent computed
# 21.37 percent computed
# 21.47 percent computed
# 21.57 percent computed
# 21.67 percent computed
# 21.77 percent computed
# 21.88 percent computed
# 21.98 percent computed
# 22.08 percent computed
# 22.18 percent computed
# 22.28 percent computed
# 22.38 percent computed
# 22.48 percent computed
# 22.58 percent computed
# 22.68 percent computed
# 22.78 percent computed
# 22.88 percent computed
# 22.98 percent computed
# 23.08 percent computed
# 23.19 percent computed
# 23.29 percent computed
# 23.39 percent computed
# 23.49 percent computed
# 23.59 percent computed
# 23.69 percent computed
# 23.79 percent computed
# 23.89 percent computed
# 23.99 percent computed
# 24.09 percent computed
# 24.19 percent computed
# 24.29 percent computed
# 24.4 percent computed
# 24.5 percent computed
# 24.6 percent computed
# 24.7 percent computed
# 24.8 percent computed
# 24.9 percent computed
# 25.0 percent computed
# 25.1 percent computed
# 25.2 percent computed
# 25.3 percent computed
# 25.4 percent computed
# 25.5 percent computed
# 25.6 percent computed
# 25.71 percent computed
# 25.81 percent computed
# 25.91 percent computed
# 26.01 percent computed
# 26.11 percent computed
# 26.21 percent computed
# 26.31 percent computed
# 26.41 percent computed
# 26.51 percent computed
# 26.61 percent computed
# 26.71 percent computed
# 26.81 percent computed
# 26.92 percent computed
# 27.02 percent computed
# 27.12 percent computed
# 27.22 percent computed
# 27.32 percent computed
# 27.42 percent computed
# 27.52 percent computed
# 27.62 percent computed
# 27.72 percent computed
# 27.82 percent computed
# 27.92 percent computed
# 28.02 percent computed
# 28.12 percent computed
# 28.23 percent computed
# 28.33 percent computed
# 28.43 percent computed
# 28.53 percent computed
# 28.63 percent computed
# 28.73 percent computed
# 28.83 percent computed
# 28.93 percent computed
# 29.03 percent computed
# 29.13 percent computed
# 29.23 percent computed
# 29.33 percent computed
# 29.44 percent computed
# 29.54 percent computed
# 29.64 percent computed
# 29.74 percent computed
# 29.84 percent computed
# 29.94 percent computed
# 30.04 percent computed
# 30.14 percent computed
# 30.24 percent computed
# 30.34 percent computed
# 30.44 percent computed
# 30.54 percent computed
# 30.65 percent computed
# 30.75 percent computed
# 30.85 percent computed
# 30.95 percent computed
# 31.05 percent computed
# 31.15 percent computed
# 31.25 percent computed
# 31.35 percent computed
# 31.45 percent computed
# 31.55 percent computed
# 31.65 percent computed
# 31.75 percent computed
# 31.85 percent computed
# 31.96 percent computed
# 32.06 percent computed
# 32.16 percent computed
# 32.26 percent computed
# 32.36 percent computed
# 32.46 percent computed
# 32.56 percent computed
# 32.66 percent computed
# 32.76 percent computed
# 32.86 percent computed
# 32.96 percent computed
# 33.06 percent computed
# 33.17 percent computed
# 33.27 percent computed
# 33.37 percent computed
# 33.47 percent computed
# 33.57 percent computed
# 33.67 percent computed
# 33.77 percent computed
# 33.87 percent computed
# 33.97 percent computed
# 34.07 percent computed
# 34.17 percent computed
# 34.27 percent computed
# 34.38 percent computed
# 34.48 percent computed
# 34.58 percent computed
# 34.68 percent computed
# 34.78 percent computed
# 34.88 percent computed
# 34.98 percent computed
# 35.08 percent computed
# 35.18 percent computed
# 35.28 percent computed
# 35.38 percent computed
# 35.48 percent computed
# 35.58 percent computed
# 35.69 percent computed
# 35.79 percent computed
# 35.89 percent computed
# 35.99 percent computed
# 36.09 percent computed
# 36.19 percent computed
# 36.29 percent computed
# 36.39 percent computed
# 36.49 percent computed
# 36.59 percent computed
# 36.69 percent computed
# 36.79 percent computed
# 36.9 percent computed
# 37.0 percent computed
# 37.1 percent computed
# 37.2 percent computed
# 37.3 percent computed
# 37.4 percent computed
# 37.5 percent computed
# 37.6 percent computed
# 37.7 percent computed
# 37.8 percent computed
# 37.9 percent computed
# 38.0 percent computed
# 38.1 percent computed
# 38.21 percent computed
# 38.31 percent computed
# 38.41 percent computed
# 38.51 percent computed
# 38.61 percent computed
# 38.71 percent computed
# 38.81 percent computed
# 38.91 percent computed
# 39.01 percent computed
# 39.11 percent computed
# 39.21 percent computed
# 39.31 percent computed
# 39.42 percent computed
# 39.52 percent computed
# 39.62 percent computed
# 39.72 percent computed
# 39.82 percent computed
# 39.92 percent computed
# 40.02 percent computed
# 40.12 percent computed
# 40.22 percent computed
# 40.32 percent computed
# 40.42 percent computed
# 40.52 percent computed
# 40.62 percent computed
# 40.73 percent computed
# 40.83 percent computed
# 40.93 percent computed
# 41.03 percent computed
# 41.13 percent computed
# 41.23 percent computed
# 41.33 percent computed
# 41.43 percent computed
# 41.53 percent computed
# 41.63 percent computed
# 41.73 percent computed
# 41.83 percent computed
# 41.94 percent computed
# 42.04 percent computed
# 42.14 percent computed
# 42.24 percent computed
# 42.34 percent computed
# 42.44 percent computed
# 42.54 percent computed
# 42.64 percent computed
# 42.74 percent computed
# 42.84 percent computed
# 42.94 percent computed
# 43.04 percent computed
# 43.15 percent computed
# 43.25 percent computed
# 43.35 percent computed
# 43.45 percent computed
# 43.55 percent computed
# 43.65 percent computed
# 43.75 percent computed
# 43.85 percent computed
# 43.95 percent computed
# 44.05 percent computed
# 44.15 percent computed
# 44.25 percent computed
# 44.35 percent computed
# 44.46 percent computed
# 44.56 percent computed
# 44.66 percent computed
# 44.76 percent computed
# 44.86 percent computed
# 44.96 percent computed
# 45.06 percent computed
# 45.16 percent computed
# 45.26 percent computed
# 45.36 percent computed
# 45.46 percent computed
# 45.56 percent computed
# 45.67 percent computed
# 45.77 percent computed
# 45.87 percent computed
# 45.97 percent computed
# 46.07 percent computed
# 46.17 percent computed
# 46.27 percent computed
# 46.37 percent computed
# 46.47 percent computed
# 46.57 percent computed
# 46.67 percent computed
# 46.77 percent computed
# 46.88 percent computed
# 46.98 percent computed
# 47.08 percent computed
# 47.18 percent computed
# 47.28 percent computed
# 47.38 percent computed
# 47.48 percent computed
# 47.58 percent computed
# 47.68 percent computed
# 47.78 percent computed
# 47.88 percent computed
# 47.98 percent computed
# 48.08 percent computed
# 48.19 percent computed
# 48.29 percent computed
# 48.39 percent computed
# 48.49 percent computed
# 48.59 percent computed
# 48.69 percent computed
# 48.79 percent computed
# 48.89 percent computed
# 48.99 percent computed
# 49.09 percent computed
# 49.19 percent computed
# 49.29 percent computed
# 49.4 percent computed
# 49.5 percent computed
# 49.6 percent computed
# 49.7 percent computed
# 49.8 percent computed
# 49.9 percent computed
# 50.0 percent computed
# 50.1 percent computed
# 50.2 percent computed
# 50.3 percent computed
# 50.4 percent computed
# 50.5 percent computed
# 50.6 percent computed
# 50.71 percent computed
# 50.81 percent computed
# 50.91 percent computed
# 51.01 percent computed
# 51.11 percent computed
# 51.21 percent computed
# 51.31 percent computed
# 51.41 percent computed
# 51.51 percent computed
# 51.61 percent computed
# 51.71 percent computed
# 51.81 percent computed
# 51.92 percent computed
# 52.02 percent computed
# 52.12 percent computed
# 52.22 percent computed
# 52.32 percent computed
# 52.42 percent computed
# 52.52 percent computed
# 52.62 percent computed
# 52.72 percent computed
# 52.82 percent computed
# 52.92 percent computed
# 53.02 percent computed
# 53.12 percent computed
# 53.23 percent computed
# 53.33 percent computed
# 53.43 percent computed
# 53.53 percent computed
# 53.63 percent computed
# 53.73 percent computed
# 53.83 percent computed
# 53.93 percent computed
# 54.03 percent computed
# 54.13 percent computed
# 54.23 percent computed
# 54.33 percent computed
# 54.44 percent computed
# 54.54 percent computed
# 54.64 percent computed
# 54.74 percent computed
# 54.84 percent computed
# 54.94 percent computed
# 55.04 percent computed
# 55.14 percent computed
# 55.24 percent computed
# 55.34 percent computed
# 55.44 percent computed
# 55.54 percent computed
# 55.65 percent computed
# 55.75 percent computed
# 55.85 percent computed
# 55.95 percent computed
# 56.05 percent computed
# 56.15 percent computed
# 56.25 percent computed
# 56.35 percent computed
# 56.45 percent computed
# 56.55 percent computed
# 56.65 percent computed
# 56.75 percent computed
# 56.85 percent computed
# 56.96 percent computed
# 57.06 percent computed
# 57.16 percent computed
# 57.26 percent computed
# 57.36 percent computed
# 57.46 percent computed
# 57.56 percent computed
# 57.66 percent computed
# 57.76 percent computed
# 57.86 percent computed
# 57.96 percent computed
# 58.06 percent computed
# 58.17 percent computed
# 58.27 percent computed
# 58.37 percent computed
# 58.47 percent computed
# 58.57 percent computed
# 58.67 percent computed
# 58.77 percent computed
# 58.87 percent computed
# 58.97 percent computed
# 59.07 percent computed
# 59.17 percent computed
# 59.27 percent computed
# 59.38 percent computed
# 59.48 percent computed
# 59.58 percent computed
# 59.68 percent computed
# 59.78 percent computed
# 59.88 percent computed
# 59.98 percent computed
# 60.08 percent computed
# 60.18 percent computed
# 60.28 percent computed
# 60.38 percent computed
# 60.48 percent computed
# 60.58 percent computed
# 60.69 percent computed
# 60.79 percent computed
# 60.89 percent computed
# 60.99 percent computed
# 61.09 percent computed
# 61.19 percent computed
# 61.29 percent computed
# 61.39 percent computed
# 61.49 percent computed
# 61.59 percent computed
# 61.69 percent computed
# 61.79 percent computed
# 61.9 percent computed
# 62.0 percent computed
# 62.1 percent computed
# 62.2 percent computed
# 62.3 percent computed
# 62.4 percent computed
# 62.5 percent computed
# 62.6 percent computed
# 62.7 percent computed
# 62.8 percent computed
# 62.9 percent computed
# 63.0 percent computed
# 63.1 percent computed
# 63.21 percent computed
# 63.31 percent computed
# 63.41 percent computed
# 63.51 percent computed
# 63.61 percent computed
# 63.71 percent computed
# 63.81 percent computed
# 63.91 percent computed
# 64.01 percent computed
# 64.11 percent computed
# 64.21 percent computed
# 64.31 percent computed
# 64.42 percent computed
# 64.52 percent computed
# 64.62 percent computed
# 64.72 percent computed
# 64.82 percent computed
# 64.92 percent computed
# 65.02 percent computed
# 65.12 percent computed
# 65.22 percent computed
# 65.32 percent computed
# 65.42 percent computed
# 65.52 percent computed
# 65.62 percent computed
# 65.73 percent computed
# 65.83 percent computed
# 65.93 percent computed
# 66.03 percent computed
# 66.13 percent computed
# 66.23 percent computed
# 66.33 percent computed
# 66.43 percent computed
# 66.53 percent computed
# 66.63 percent computed
# 66.73 percent computed
# 66.83 percent computed
# 66.94 percent computed
# 67.04 percent computed
# 67.14 percent computed
# 67.24 percent computed
# 67.34 percent computed
# 67.44 percent computed
# 67.54 percent computed
# 67.64 percent computed
# 67.74 percent computed
# 67.84 percent computed
# 67.94 percent computed
# 68.04 percent computed
# 68.15 percent computed
# 68.25 percent computed
# 68.35 percent computed
# 68.45 percent computed
# 68.55 percent computed
# 68.65 percent computed
# 68.75 percent computed
# 68.85 percent computed
# 68.95 percent computed
# 69.05 percent computed
# 69.15 percent computed
# 69.25 percent computed
# 69.35 percent computed
# 69.46 percent computed
# 69.56 percent computed
# 69.66 percent computed
# 69.76 percent computed
# 69.86 percent computed
# 69.96 percent computed
# 70.06 percent computed
# 70.16 percent computed
# 70.26 percent computed
# 70.36 percent computed
# 70.46 percent computed
# 70.56 percent computed
# 70.67 percent computed
# 70.77 percent computed
# 70.87 percent computed
# 70.97 percent computed
# 71.07 percent computed
# 71.17 percent computed
# 71.27 percent computed
# 71.37 percent computed
# 71.47 percent computed
# 71.57 percent computed
# 71.67 percent computed
# 71.77 percent computed
# 71.88 percent computed
# 71.98 percent computed
# 72.08 percent computed
# 72.18 percent computed
# 72.28 percent computed
# 72.38 percent computed
# 72.48 percent computed
# 72.58 percent computed
# 72.68 percent computed
# 72.78 percent computed
# 72.88 percent computed
# 72.98 percent computed
# 73.08 percent computed
# 73.19 percent computed
# 73.29 percent computed
# 73.39 percent computed
# 73.49 percent computed
# 73.59 percent computed
# 73.69 percent computed
# 73.79 percent computed
# 73.89 percent computed
# 73.99 percent computed
# 74.09 percent computed
# 74.19 percent computed
# 74.29 percent computed
# 74.4 percent computed
# 74.5 percent computed
# 74.6 percent computed
# 74.7 percent computed
# 74.8 percent computed
# 74.9 percent computed
# 75.0 percent computed
# 75.1 percent computed
# 75.2 percent computed
# 75.3 percent computed
# 75.4 percent computed
# 75.5 percent computed
# 75.6 percent computed
# 75.71 percent computed
# 75.81 percent computed
# 75.91 percent computed
# 76.01 percent computed
# 76.11 percent computed
# 76.21 percent computed
# 76.31 percent computed
# 76.41 percent computed
# 76.51 percent computed
# 76.61 percent computed
# 76.71 percent computed
# 76.81 percent computed
# 76.92 percent computed
# 77.02 percent computed
# 77.12 percent computed
# 77.22 percent computed
# 77.32 percent computed
# 77.42 percent computed
# 77.52 percent computed
# 77.62 percent computed
# 77.72 percent computed
# 77.82 percent computed
# 77.92 percent computed
# 78.02 percent computed
# 78.12 percent computed
# 78.23 percent computed
# 78.33 percent computed
# 78.43 percent computed
# 78.53 percent computed
# 78.63 percent computed
# 78.73 percent computed
# 78.83 percent computed
# 78.93 percent computed
# 79.03 percent computed
# 79.13 percent computed
# 79.23 percent computed
# 79.33 percent computed
# 79.44 percent computed
# 79.54 percent computed
# 79.64 percent computed
# 79.74 percent computed
# 79.84 percent computed
# 79.94 percent computed
# 80.04 percent computed
# 80.14 percent computed
# 80.24 percent computed
# 80.34 percent computed
# 80.44 percent computed
# 80.54 percent computed
# 80.65 percent computed
# 80.75 percent computed
# 80.85 percent computed
# 80.95 percent computed
# 81.05 percent computed
# 81.15 percent computed
# 81.25 percent computed
# 81.35 percent computed
# 81.45 percent computed
# 81.55 percent computed
# 81.65 percent computed
# 81.75 percent computed
# 81.85 percent computed
# 81.96 percent computed
# 82.06 percent computed
# 82.16 percent computed
# 82.26 percent computed
# 82.36 percent computed
# 82.46 percent computed
# 82.56 percent computed
# 82.66 percent computed
# 82.76 percent computed
# 82.86 percent computed
# 82.96 percent computed
# 83.06 percent computed
# 83.17 percent computed
# 83.27 percent computed
# 83.37 percent computed
# 83.47 percent computed
# 83.57 percent computed
# 83.67 percent computed
# 83.77 percent computed
# 83.87 percent computed
# 83.97 percent computed
# 84.07 percent computed
# 84.17 percent computed
# 84.27 percent computed
# 84.38 percent computed
# 84.48 percent computed
# 84.58 percent computed
# 84.68 percent computed
# 84.78 percent computed
# 84.88 percent computed
# 84.98 percent computed
# 85.08 percent computed
# 85.18 percent computed
# 85.28 percent computed
# 85.38 percent computed
# 85.48 percent computed
# 85.58 percent computed
# 85.69 percent computed
# 85.79 percent computed
# 85.89 percent computed
# 85.99 percent computed
# 86.09 percent computed
# 86.19 percent computed
# 86.29 percent computed
# 86.39 percent computed
# 86.49 percent computed
# 86.59 percent computed
# 86.69 percent computed
# 86.79 percent computed
# 86.9 percent computed
# 87.0 percent computed
# 87.1 percent computed
# 87.2 percent computed
# 87.3 percent computed
# 87.4 percent computed
# 87.5 percent computed
# 87.6 percent computed
# 87.7 percent computed
# 87.8 percent computed
# 87.9 percent computed
# 88.0 percent computed
# 88.1 percent computed
# 88.21 percent computed
# 88.31 percent computed
# 88.41 percent computed
# 88.51 percent computed
# 88.61 percent computed
# 88.71 percent computed
# 88.81 percent computed
# 88.91 percent computed
# 89.01 percent computed
# 89.11 percent computed
# 89.21 percent computed
# 89.31 percent computed
# 89.42 percent computed
# 89.52 percent computed
# 89.62 percent computed
# 89.72 percent computed
# 89.82 percent computed
# 89.92 percent computed
# 90.02 percent computed
# 90.12 percent computed
# 90.22 percent computed
# 90.32 percent computed
# 90.42 percent computed
# 90.52 percent computed
# 90.62 percent computed
# 90.73 percent computed
# 90.83 percent computed
# 90.93 percent computed
# 91.03 percent computed
# 91.13 percent computed
# 91.23 percent computed
# 91.33 percent computed
# 91.43 percent computed
# 91.53 percent computed
# 91.63 percent computed
# 91.73 percent computed
# 91.83 percent computed
# 91.94 percent computed
# 92.04 percent computed
# 92.14 percent computed
# 92.24 percent computed
# 92.34 percent computed
# 92.44 percent computed
# 92.54 percent computed
# 92.64 percent computed
# 92.74 percent computed
# 92.84 percent computed
# 92.94 percent computed
# 93.04 percent computed
# 93.15 percent computed
# 93.25 percent computed
# 93.35 percent computed
# 93.45 percent computed
# 93.55 percent computed
# 93.65 percent computed
# 93.75 percent computed
# 93.85 percent computed
# 93.95 percent computed
# 94.05 percent computed
# 94.15 percent computed
# 94.25 percent computed
# 94.35 percent computed
# 94.46 percent computed
# 94.56 percent computed
# 94.66 percent computed
# 94.76 percent computed
# 94.86 percent computed
# 94.96 percent computed
# 95.06 percent computed
# 95.16 percent computed
# 95.26 percent computed
# 95.36 percent computed
# 95.46 percent computed
# 95.56 percent computed
# 95.67 percent computed
# 95.77 percent computed
# 95.87 percent computed
# 95.97 percent computed
# 96.07 percent computed
# 96.17 percent computed
# 96.27 percent computed
# 96.37 percent computed
# 96.47 percent computed
# 96.57 percent computed
# 96.67 percent computed
# 96.77 percent computed
# 96.88 percent computed
# 96.98 percent computed
# 97.08 percent computed
# 97.18 percent computed
# 97.28 percent computed
# 97.38 percent computed
# 97.48 percent computed
# 97.58 percent computed
# 97.68 percent computed
# 97.78 percent computed
# 97.88 percent computed
# 97.98 percent computed
# 98.08 percent computed
# 98.19 percent computed
# 98.29 percent computed
# 98.39 percent computed
# 98.49 percent computed
# 98.59 percent computed
# 98.69 percent computed
# 98.79 percent computed
# 98.89 percent computed
# 98.99 percent computed
# 99.09 percent computed
# 99.19 percent computed
# 99.29 percent computed
# 99.4 percent computed
# 99.5 percent computed
# 99.6 percent computed
# 99.7 percent computed
# 99.8 percent computed
# 99.9 percent computed
# 100.0 percent computed
# CPU times: user 15.1 s, sys: 135 ms, total: 15.3 s
# Wall time: 15.3 s

# %% [markdown]
# **About the resulting database:**
#  * Has 546 IRIS overlaying at least one slow zone.
#  * The other 446 are never-treated units, that is, they never receive direct treatment in the considered period.
#  * The null observations are removed, as they are empty and consists of the set of never-treated.
#  * The geometry consists of the overlaid part of slow zones inside each specific IRIS.
#  * I did not remove the slow zones with missing information on the date of implementation, meaning there are 129 observations with no information on the implementation date. Grouping at the IRIS level, there is just
