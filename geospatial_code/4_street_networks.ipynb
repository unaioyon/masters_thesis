# %% [markdown]
# # Exploring street networks in Paris

# %%
# Import packages
# Operational
import os
from os.path import isfile, join
import zipfile

# Basic
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Scale for maps
from matplotlib_scalebar.scalebar import ScaleBar
# Personalised legends for maps
from matplotlib.patches import Patch
from matplotlib.lines import Line2D

# Geospatial
import geopandas as gpd
import rasterio as rio
import fiona
import contextily
import osmnx
import prettymaps
from shapely import geometry

# %%
# Set working directory
os.chdir("/Users/unaioyon/Desktop/masters_thesis/data/fra")

# %% [markdown]
# ## 0. Preliminary set-up

# %%
# Import data
streets = gpd.read_file("streets/VOIE.shp")

# %%
osmnx.graph_from_address?

# %%
# Import Paris street network
paris = osmnx.graph_from_address("Paris (7444), France", network_type = "all")

# %%
osmnx.plot_graph?

# %%
osmnx.plot_graph(paris, edge_color = "blue", node_edgecolor = "red")
# Out:
# (<Figure size 800x800 with 1 Axes>, <AxesSubplot: >)

# %%
dir(osmnx)
# Out:
# ['__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__version__',
#  '_api',
#  '_errors',
#  '_polygon_features',
#  '_version',
#  'add_edge_bearings',
#  'add_edge_grades',
#  'add_edge_speeds',
#  'add_edge_travel_times',
#  'add_node_elevations_google',
#  'add_node_elevations_raster',
#  'basic_stats',
#  'bearing',
#  'citation',
#  'config',
#  'consolidate_intersections',
#  'distance',
#  'downloader',
#  'elevation',
#  'folium',
#  'geocode',
#  'geocode_to_gdf',
#  'geocoder',
#  'geometries',
#  'geometries_from_address',
#  'geometries_from_bbox',
#  'geometries_from_place',
#  'geometries_from_point',
#  'geometries_from_polygon',
#  'geometries_from_xml',
#  'get_digraph',
#  'get_undirected',
#  'graph',
#  'graph_from_address',
#  'graph_from_bbox',
#  'graph_from_gdfs',
#  'graph_from_place',
#  'graph_from_point',
#  'graph_from_polygon',
#  'graph_from_xml',
# ...

# %%
osmnx.geometries_from_point?

# %%
# Import Córdoba
cor = osmnx.geometries_from_place("Córdoba, Spain", tags = {"amenity": ["bar", "restaurant"]})

# %%
cordoba = osmnx.graph_from_place("Córdoba, Spain")

# %%
osmnx.plot_graph(cordoba, figsize = (30, 30), bgcolor = "white",
                node_color = "")
# Out:
# (<Figure size 3000x3000 with 1 Axes>, <AxesSubplot: >)

# %%
osmnx.plot_graph(cordoba,
                 show=False,
                 close=False,
                 edge_color = "black",
                 node_size = 0,
                 bgcolor = "white")
# Out:
# (<Figure size 800x800 with 1 Axes>, <AxesSubplot: >)

# %%
# Ploteándolo
fig, ax = osmnx.plot_graph(cordoba,
                 show=False,
                 close=False,
                 edge_color = "black",
                 node_size = 0,
                 bgcolor = "white")
osmnx.project_gdf(cor).plot(ax = ax, color = "blue",markersize = 30, zorder = 9)
plt.show()

# %%
ax
# Out:
# <AxesSubplot: >
